# %% [markdown]
# Taking the ROI as a rectangular selection and comparing area calculated with that manually calculated with a graphsheet

# %%
import numpy as np
import pandas as pd
import easygui 
import matplotlib.pyplot as plt

import matplotlib.ticker as ticker


import plotly.plotly as py
import cufflinks as cf
# %matplotlib inline

# %%
dp='/home/subhar/Desktop/data_acquisition/Mound_E/0-60%/new_setup_ completeBlack/2017_08_04/sanitycheck'
#path=easygui.fileopenbox(default=dp,filetypes=['*.csv'])

path='/home/subhar/Desktop/data_acquisition/Mound_E/0-60%/new_setup_ completeBlack/2017_08_04/sanitycheck/Results2017_08_04changeSC.csv'
data_date=path.split('/')[-2]

# %%
df=pd.read_csv(path)
df.head()
# Out:
#        Area1  %Area1  Filled area  empty area  change in area  \
# 0  1  34.359  28.793     9.892987   24.466013        0.000000
# 1  2  34.359  29.044     9.979228   24.379772       -0.003525
# 2  3  34.359  28.705     9.862751   24.496249        0.001236
# 3  4  34.359  28.740     9.874777   24.484223        0.000744
# 4  5  34.359  28.447     9.774105   24.584895        0.004859
#
#    change in area%  Absolute 0%   Area2  %Area2      ...       \
# 0         0.000000     0.000000  36.003  31.734      ...
# 1        -0.352493     0.352493  36.003  31.903      ...
# 2         0.123583     0.123583  36.003  31.916      ...
# 3         0.074431     0.074431  36.003  31.937      ...
# 4         0.485907     0.485907  36.003  31.973      ...
#
#    change in area.3  change in area%.3  Absolute 45%   Area5  %Area5  \
# 0          0.000000           0.000000      0.000000  35.698  34.518
# 1         -0.000169          -0.016859      0.016859  35.698  34.588
# ...

# %%
df1 = df.rename(index=str, columns={"Absolute 0%": "0%","Absolute 15%": "15%","Absolute 30%": "30%","Absolute 45%": "45%","Absolute 60%": "60%"})

df2=df1[['0%','15%','30%','45%','60%']]

df2
# Out:
#            0%       15%        30%       45%       60%
# 0    0.000000  0.000000   0.000000  0.000000  0.000000
# 1    0.352493  0.247561   0.523402  0.016859  0.106900
# 2    0.123583  0.266604   0.791989  0.077272  0.138969
# 3    0.074431  0.297366   0.661139  0.289419  0.108427
# 4    0.485907  0.350101   1.114294  0.056198  0.140497
# 5    0.153075  0.111329   1.112917  0.078677  0.251978
# 6    0.636173  0.360355   1.490317  0.050578  0.224489
# 7    0.139031  0.238772   2.070191  0.037934  0.197001
# 8    0.036513  0.023438   2.209306  0.005620  0.238233
# 9    0.196610  0.039551   2.925539  0.075867  0.212272
# 10   0.015448  0.016113   3.191372  0.001405  0.256559
# 11   0.188184  0.117189   3.935153  0.023884  0.290156
# 12   0.351089  0.273928   4.318063  0.025289  0.221435
# 13   0.080048  0.115724   4.842842  0.047768  0.164931
# 14   0.012639  0.506841   5.349715  0.025289  0.200055
# 15   0.136223  0.587408   6.023250  0.004215  0.273358
# ...

# %%
a=df2.plot(figsize=(8,6))
a.set_xlabel("Time (mins)")
a.set_ylabel("Area fraction built (percentage)")
a.set_title(data_date)
plt.savefig(data_date+'.png',dpi=300)
