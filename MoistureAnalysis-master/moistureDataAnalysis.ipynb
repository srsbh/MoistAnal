# %%
import numpy as np
import pandas as pd
import easygui 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dp='/home/subhar/data/'
path=easygui.fileopenbox(default=dp)

# %%
df=pd.read_csv(path)

# %%
df
# Out:
#             Area1   Mean1  Min1  Max1  %Area1    Area2   Mean2  Min2  Max2  \
# 0      1  1440006  77.421     0   255  30.361  1424839  82.510     0   255
# 1      2  1440006  77.265     0   255  30.300  1424839  81.508     0   255
# 2      3  1440006  77.748     0   255  30.489  1424839  82.303     0   255
# 3      4  1440006  78.095     0   255  30.625  1424839  79.469     0   255
# 4      5  1440006  77.399     0   255  30.353  1424839  83.069     0   255
# 5      6  1440006  77.912     0   255  30.554  1424839  83.831     0   255
# 6      7  1440006  78.101     0   255  30.628  1424839  84.126     0   255
# 7      8  1440006  78.220     0   255  30.675  1424839  84.108     0   255
# 8      9  1440006  78.113     0   255  30.633  1424839  84.919     0   255
# 9     10  1440006  77.847     0   255  30.528  1424839  84.724     0   255
# 10    11  1440006  77.748     0   255  30.489  1424839  84.192     0   255
# ...

# %%
df1 = df.rename(index=str, columns={"%Area1": "15%","%Area2": "30%","%Area3": "45%","%Area4": "60%","%Area5": "75%"})
# Out:
#             Area1   Mean1  Min1  Max1     15%    Area2   Mean2  Min2  Max2  \
# 0      1  1440006  77.421     0   255  30.361  1424839  82.510     0   255
# 1      2  1440006  77.265     0   255  30.300  1424839  81.508     0   255
# 2      3  1440006  77.748     0   255  30.489  1424839  82.303     0   255
# 3      4  1440006  78.095     0   255  30.625  1424839  79.469     0   255
# 4      5  1440006  77.399     0   255  30.353  1424839  83.069     0   255
# 5      6  1440006  77.912     0   255  30.554  1424839  83.831     0   255
# 6      7  1440006  78.101     0   255  30.628  1424839  84.126     0   255
# 7      8  1440006  78.220     0   255  30.675  1424839  84.108     0   255
# 8      9  1440006  78.113     0   255  30.633  1424839  84.919     0   255
# 9     10  1440006  77.847     0   255  30.528  1424839  84.724     0   255
# 10    11  1440006  77.748     0   255  30.489  1424839  84.192     0   255
# ...

# %%
df2=df1[['15%','30%','45%','60%','75%']]
# nFrame=229
# df2=df2[0:nFrame-1]
df2
# Out:
#         15%     30%     45%     60%     75%
# 0    30.361  32.357  28.652  32.759  35.138
# 1    30.300  31.964  28.433  32.470  34.975
# 2    30.489  32.276  28.702  32.517  34.536
# 3    30.625  31.164  29.516  33.119  35.542
# 4    30.353  32.576  29.082  32.867  35.547
# 5    30.554  32.875  29.538  33.234  35.518
# 6    30.628  32.991  30.065  33.541  35.676
# 7    30.675  32.983  30.374  33.523  35.614
# 8    30.633  33.302  30.947  33.566  35.390
# 9    30.528  33.225  31.439  33.567  35.348
# 10   30.489  33.016  31.951  33.561  35.508
# 11   30.496  33.277  32.447  33.557  35.270
# 12   30.397  33.137  32.617  33.482  35.455
# 13   30.294  33.198  33.225  33.539  35.444
# 14   30.220  33.131  33.518  33.695  35.507
# 15   30.486  33.131  33.754  33.506  35.475
# 16   30.375  33.278  34.069  33.554  35.493
# 17   30.237  33.377  34.395  33.464  35.280
# 18   30.367  33.205  34.541  33.436  35.598
# 19   30.409  33.419  34.766  33.518  35.617
# ...

# %%
a=df2.plot()
a.set_xlabel("Time (mins)")
a.set_ylabel("Area fraction built (percentage)")

# %%
a.savefig('2017_07_06'+'.png',dpi=300)#savefigure
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-aea888f7853a> in <module>()
# ----> 1 a.savefig('2017_07_06'+'.png',dpi=300)#savefigure
#
# AttributeError: 'AxesSubplot' object has no attribute 'savefig'

# %%
b
# Out:
# 2

# %%
# Out:
# 6
